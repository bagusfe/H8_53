# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.2.4'

# %%
df = pd.read_csv("dataset/nbaallelo.csv")

# %%
num_rows, num_cols = df.shape
print("num of rows:", num_rows)
print("num of cols:", num_cols)
# Out:
# num of rows: 126314
# num of cols: 23

# %%
df.head(10)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7          4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8          5  194611020STB   NBA        1     1947  11/2/1946           1
# 9          5  194611020STB   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id       fran_id  ...  win_equiv  opp_id      opp_fran  \
# 0            0     TRH       Huskies  ...  40.294830     NYK        Knicks
# ...

# %%
df.tail(15)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126299      63150  201505260CLE   NBA        1     2015  5/26/2015
# 126300      63151  201505270GSW   NBA        1     2015  5/27/2015
# 126301      63151  201505270GSW   NBA        0     2015  5/27/2015
# 126302      63152  201506040GSW   NBA        1     2015   6/4/2015
# 126303      63152  201506040GSW   NBA        0     2015   6/4/2015
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126305      63153  201506070GSW   NBA        0     2015   6/7/2015
# 126306      63154  201506090CLE   NBA        1     2015   6/9/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126308      63155  201506110CLE   NBA        1     2015  6/11/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# ...

# %%
with pd.option_context("display.max.columns", None, "display.precision", 2):
    display(df.head())
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts          elo_i          elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982    1495.236055    1495.236055
# std         0.244499      14.814845     112.139945     112.461687
# min         0.000000       0.000000    1091.644500    1085.774400
# ...

# %%
df.describe(include="object")
# Out:
#              game_id   lg_id  date_game team_id fran_id  opp_id opp_fran  \
# count         126314  126314     126314  126314  126314  126314   126314
# unique         63157       2      12426     104      53     104       53
# top     199403240SAC     NBA  4/16/2014     BOS  Lakers     BOS   Lakers
# freq               2  118016         30    5997    6024    5997     6024
#
#        game_location game_result           notes
# count         126314      126314            5424
# unique             3           2             231
# top                H           L  at New York NY
# freq           63138       63157             440

# %%
df.describe(include="all").T
# Out:
#                   count unique             top    freq         mean  \
# gameorder      126314.0    NaN             NaN     NaN      31579.0
# game_id          126314  63157    199403240SAC       2          NaN
# lg_id            126314      2             NBA  118016          NaN
# _iscopy        126314.0    NaN             NaN     NaN          0.5
# year_id        126314.0    NaN             NaN     NaN  1988.200374
# date_game        126314  12426       4/16/2014      30          NaN
# seasongame     126314.0    NaN             NaN     NaN    43.533733
# is_playoffs    126314.0    NaN             NaN     NaN     0.063857
# team_id          126314    104             BOS    5997          NaN
# fran_id          126314     53          Lakers    6024          NaN
# pts            126314.0    NaN             NaN     NaN   102.729982
# elo_i          126314.0    NaN             NaN     NaN  1495.236055
# elo_n          126314.0    NaN             NaN     NaN  1495.236055
# ...

# %%
print(type(df.columns))
print(df.columns)
# Out:
# <class 'pandas.core.indexes.base.Index'>
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#        'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#        'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# gameorder          int64
# game_id           object
# lg_id             object
# _iscopy            int64
# year_id            int64
# date_game         object
# seasongame         int64
# is_playoffs        int64
# team_id           object
# fran_id           object
# pts                int64
# elo_i            float64
# elo_n            float64
# win_equiv        float64
# opp_id            object
# opp_fran          object
# opp_pts            int64
# opp_elo_i        float64
# opp_elo_n        float64
# game_location     object
# game_result       object
# forecast         float64
# notes             object
# dtype: object

# %% [markdown]
# ## Series

# %%
revenues = pd.Series([5555, 7000, 1980])
print(revenues)
print(type(revenues))
print(revenues.dtypes)
# Out:
# 0    5555
# 1    7000
# 2    1980
# dtype: int64
# <class 'pandas.core.series.Series'>
# int64

# %%
print("index:", revenues.index)
# Out:
# index: RangeIndex(start=0, stop=3, step=1)

# %%
revenues.values, revenues.values.shape
# Out:
# (array([5555, 7000, 1980]), (3,))

# %%
city_revenues = pd.Series(
    [4200, 8000, 6500],
    index=["Surabaya", "Jakarta", "Bandung"],
    name="income",
)
print(city_revenues)
# Out:
# Surabaya    4200
# Jakarta     8000
# Bandung     6500
# Name: income, dtype: int64

# %%
another_revenues = pd.Series(
    {"surabaya": 4200, "jakarta": 8000, "bandung": 6500},
    name="revenues"
)
print(another_revenues)
# Out:
# surabaya    4200
# jakarta     8000
# bandung     6500
# Name: revenues, dtype: int64

# %%
dict_revenues = {"surabaya": 4200, "jakarta": 8000, "bandung": 6500}

# %%
another_revenues.index
# Out:
# Index(['surabaya', 'jakarta', 'bandung'], dtype='object')

# %%
dict_revenues.items(), dict_revenues.keys()
# Out:
# (dict_items([('surabaya', 4200), ('jakarta', 8000), ('bandung', 6500)]),
#  dict_keys(['surabaya', 'jakarta', 'bandung']))

# %%
print(another_revenues["surabaya"])
print(revenues[0])
print(city_revenues["Surabaya"])
# Out:
# 4200
# 5555
# 4200

# %% [markdown]
# ## DataFrame

# %%
manual_df = pd.DataFrame(
    [[5, 1000], [8, 1500]],
    index=["amsterdam", "tokyo"],
    columns=["employee_count", "revenue"]
)
manual_df
# Out:
#            employee_count  revenue
# amsterdam               5     1000
# tokyo                   8     1500

# %%
manual_df["employee_count"]
# Out:
# amsterdam    5
# tokyo        8
# Name: employee_count, dtype: int64

# %%
manual_df["revenue"]
# Out:
# amsterdam    1000
# tokyo        1500
# Name: revenue, dtype: int64

# %%
df["fran_id"]
# Out:
# 0           Huskies
# 1            Knicks
# 2             Stags
# 3            Knicks
# 4           Falcons
#             ...
# 126309    Cavaliers
# 126310     Warriors
# 126311    Cavaliers
# 126312    Cavaliers
# 126313     Warriors
# Name: fran_id, Length: 126314, dtype: object

# %%
d = {
    "city": ["jakarta", "bandung", "surabaya", "bandung", "jogja"],
    "name": ["thomas", "made", "joko", "william", "tono"],
}
start_index = 10

pd.DataFrame(
    d,
#     index=range(start_index, start_index+len(d["city"]))
#     index=[10, 11, 12, 13, 14]
)
# Out:
#        city     name
# 0   jakarta   thomas
# 1   bandung     made
# 2  surabaya     joko
# 3   bandung  william
# 4     jogja     tono

# %%
city_revenues.reset_index(drop=True)
# Out:
# 0    4200
# 1    8000
# 2    6500
# Name: income, dtype: int64

# %%
df_revenue = pd.DataFrame(
    {
        "revenues": revenues,
        "another_revenues": city_revenues.reset_index(drop=True),
    },
)
df_revenue
# Out:
#    revenues  another_revenues
# 0      5555              4200
# 1      7000              8000
# 2      1980              6500

# %%
df_revenue.values
# Out:
# array([[5555, 4200],
#        [7000, 8000],
#        [1980, 6500]])

# %% [markdown]
# ## Methods in DataFrame and Series

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
df["year_id"].value_counts()
# Out:
# 2014    2638
# 2006    2638
# 2008    2632
# 2009    2630
# 2013    2628
#         ...
# 1959     620
# 1958     618
# 1955     618
# 1957     614
# 1948     430
# Name: year_id, Length: 69, dtype: int64

# %%
df["year_id"].value_counts().head(10)
# Out:
# 2014    2638
# 2006    2638
# 2008    2632
# 2009    2630
# 2013    2628
# 2005    2628
# 2010    2624
# 2011    2622
# 2015    2622
# 2007    2618
# Name: year_id, dtype: int64

# %%
df["year_id"].value_counts().tail(10)
# Out:
# 1947    700
# 1954    694
# 1961    682
# 1960    650
# 1956    622
# 1959    620
# 1958    618
# 1955    618
# 1957    614
# 1948    430
# Name: year_id, dtype: int64

# %%
df["year_id"].nunique()
# Out:
# 69

# %%
df["year_id"].unique()
# Out:
# array([1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957,
#        1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968,
#        1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979,
#        1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990,
#        1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#        2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013, 2014, 2015])

# %%
df["year_id"].value_counts().index
# Out:
# Int64Index([2014, 2006, 2008, 2009, 2013, 2005, 2010, 2011, 2015, 2007, 2003,
#             2004, 2000, 1997, 2002, 2001, 1998, 1996, 1975, 1971, 1972, 1974,
#             1973, 1994, 1993, 1995, 1992, 1990, 1991, 1976, 1970, 1989, 1969,
#             2012, 1988, 1984, 1987, 1986, 1985, 1981, 1968, 1982, 1983, 1979,
#             1977, 1978, 1980, 1999, 1950, 1967, 1963, 1962, 1966, 1964, 1965,
#             1949, 1951, 1953, 1952, 1947, 1954, 1961, 1960, 1956, 1959, 1958,
#             1955, 1957, 1948],
#            dtype='int64')

# %% [markdown]
# ## Indexing and Accessing Values in DataFrame

# %%
df.columns
# Out:
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#        'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#        'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#       dtype='object')

# %%
summary_cols = ["year_id", "team_id", "opp_id", "pts", "opp_pts"]
df_summary = df[summary_cols].copy()
df_summary
# Out:
#         year_id team_id opp_id  pts  opp_pts
# 0          1947     TRH    NYK   66       68
# 1          1947     NYK    TRH   68       66
# 2          1947     CHS    NYK   63       47
# 3          1947     NYK    CHS   47       63
# 4          1947     DTF    WSC   33       50
# ...         ...     ...    ...  ...      ...
# 126309     2015     CLE    GSW   82      103
# 126310     2015     GSW    CLE  104       91
# 126311     2015     CLE    GSW   91      104
# 126312     2015     CLE    GSW   97      105
# 126313     2015     GSW    CLE  105       97
#
# [126314 rows x 5 columns]

# %%
df_summary.loc[:5, ["pts", "opp_pts"]]
# Out:
#    pts  opp_pts
# 0   66       68
# 1   68       66
# 2   63       47
# 3   47       63
# 4   33       50
# 5   50       33

# %%
df_summary.loc[[0, 2, 4], ["team_id", "pts"]]
# Out:
#   team_id  pts
# 0     TRH   66
# 2     CHS   63
# 4     DTF   33

# %%
df_summary.iloc[:5, [-2, -1]]
# Out:
#    pts  opp_pts
# 0   66       68
# 1   68       66
# 2   63       47
# 3   47       63
# 4   33       50

# %%
df_summary.iloc[[0, 2, 4], [1, -2]]
# Out:
#   team_id  pts
# 0     TRH   66
# 2     CHS   63
# 4     DTF   33

# %%
df_summary.loc[0]
# Out:
# year_id    1947
# team_id     TRH
# opp_id      NYK
# pts          66
# opp_pts      68
# Name: 0, dtype: object

# %%
df_summary.loc[:4]
# Out:
#    year_id team_id opp_id  pts  opp_pts
# 0     1947     TRH    NYK   66       68
# 1     1947     NYK    TRH   68       66
# 2     1947     CHS    NYK   63       47
# 3     1947     NYK    CHS   47       63
# 4     1947     DTF    WSC   33       50

# %%
manual_df.loc["amsterdam"]
# Out:
# employee_count       5
# revenue           1000
# Name: amsterdam, dtype: int64

# %%
manual_df.loc[:"amsterdam"]
# Out:
#            employee_count  revenue
# amsterdam               5     1000

# %%
df_summary[df_summary["team_id"] == "GSW"]
# Out:
#         year_id team_id opp_id  pts  opp_pts
# 24045      1972     GSW    BOS   97       75
# 24064      1972     GSW    BAL   93      108
# 24099      1972     GSW    NYK   84       93
# 24112      1972     GSW    CLE  115       98
# 24155      1972     GSW    DET  115      109
# ...         ...     ...    ...  ...      ...
# 126305     2015     GSW    CLE   93       95
# 126306     2015     GSW    CLE   91       96
# 126308     2015     GSW    CLE  103       82
# 126310     2015     GSW    CLE  104       91
# 126313     2015     GSW    CLE  105       97
#
# [3701 rows x 5 columns]

# %%
df_gsw_win = df_summary[
    (df_summary["team_id"] == "GSW")
    & (df_summary.pts > df_summary.opp_pts)
]

# %%
df_gsw_win["opp_id"].value_counts()
# Out:
# POR    91
# PHO    86
# LAC    80
# SEA    80
# LAL    77
# DEN    75
# HOU    74
# DAL    70
# UTA    66
# SAC    65
# DET    60
# SAS    58
# MIN    57
# PHI    57
# NYK    55
# CLE    55
# ATL    54
# CHI    50
# MIL    50
# BOS    45
# NJN    39
# IND    38
# WSB    33
# KCK    28
# MIA    26
# MEM    25
# TOR    22
# ORL    22
# BUF    20
# WAS    19
# SDC    17
# VAN    15
# NOH    14
# CHH    12
# NOP    10
# OKC     9
# CHA     9
# KCO     9
# NOJ     8
# BAL     5
# BRK     4
# NOK     4
# NYN     3
# CIN     3
# CHO     2
# CAP     1
# Name: opp_id, dtype: int64

# %%
df_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   year_id  126314 non-null  int64
#  1   team_id  126314 non-null  object
#  2   opp_id   126314 non-null  object
#  3   pts      126314 non-null  int64
#  4   opp_pts  126314 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 4.8+ MB

# %%
df_summary.loc[
    (df_summary.year_id >= 2005)
    & (df_summary.pts > df_summary.opp_pts),
    "team_id"
].value_counts()
# Out:
# SAS    725
# DAL    624
# MIA    611
# PHO    553
# LAL    550
# HOU    547
# CHI    544
# BOS    540
# DEN    527
# CLE    520
# DET    486
# IND    482
# MEM    477
# UTA    474
# ORL    470
# GSW    467
# ATL    464
# LAC    462
# POR    451
# TOR    403
# WAS    398
# PHI    384
# OKC    378
# MIL    370
# NYK    366
# SAC    341
# MIN    300
# CHA    293
# NJN    269
# NOH    264
# SEA    144
# BRK    141
# NOP     79
# NOK     77
# CHO     33
# Name: team_id, dtype: int64

# %%
"hacktiv8".startswith("hak"), "hacktiv8".endswith("8")
# Out:
# (False, True)

# %%
df.loc[
    (df["fran_id"] == "Stars") & (df["team_id"].str.startswith("LA")),
    ["year_id", "team_id", "fran_id"]
]
# Out:
#        year_id team_id fran_id
# 17266     1969     LAS   Stars
# 17276     1969     LAS   Stars
# 17303     1969     LAS   Stars
# 17343     1969     LAS   Stars
# 17376     1969     LAS   Stars
# ...        ...     ...     ...
# 21538     1970     LAS   Stars
# 21540     1970     LAS   Stars
# 21543     1970     LAS   Stars
# 21544     1970     LAS   Stars
# 21546     1970     LAS   Stars
#
# [179 rows x 3 columns]

# %%
df_gsw_win.sort_values(["pts", "opp_pts"], ascending=False)
# Out:
#        year_id team_id opp_id  pts  opp_pts
# 64288     1991     GSW    DEN  162      158
# 61146     1989     GSW    SAC  155      143
# 50356     1984     GSW    SAS  154      133
# 68535     1992     GSW    NJN  153      148
# 66663     1992     GSW    SAC  153       91
# ...        ...     ...    ...  ...      ...
# 84550     1999     GSW    LAL   81       76
# 81887     1998     GSW    DEN   81       69
# 86824     2000     GSW    ATL   80       75
# 95708     2004     GSW    POR   78       72
# 74644     1995     GSW    DEN   77       73
#
# [1702 rows x 5 columns]

# %% [markdown]
# ## Grouping

# %%
df.groupby("fran_id")[["pts", "opp_pts"]].sum()
# Out:
#                  pts  opp_pts
# fran_id
# Baltimore      37219    38924
# Bombers        17793    18059
# Bucks         418326   414777
# Bulls         437269   433780
# Capitols       22387    21815
# Cavaliers     380416   384513
# Celtics       626484   611049
# Clippers      380523   393976
# Colonels       94435    91964
# Condors        49642    50525
# Denver          4818     5530
# Falcons         3797     3917
# Floridians     49568    50029
# Grizzlies     157683   162133
# Hawks         567261   569378
# Heat          229103   228146
# Hornets        84489    88315
# Huskies         3995     4260
# Ironmen         3674     4057
# Jazz          363155   360196
# Jets            4482     4765
# Kings         569245   576070
# Knicks        582497   583423
# Lakers        637444   619593
# Magic         219436   219495
# Mavericks     309239   309357
# Nets          417809   425386
# Nuggets       445780   446878
# Olympians      22864    23026
# ...

# %%
df_la_base_team = df.loc[
    df["team_id"].str.startswith("LA")
]
df_la_base_team
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 9730         4866  196010190CIN   NBA        1     1961  10/19/1960
# 9739         4870  196010220STL   NBA        1     1961  10/22/1960
# 9744         4873  196010240LAL   NBA        0     1961  10/24/1960
# 9747         4874  196010250LAL   NBA        0     1961  10/25/1960
# 9756         4879  196010280GSW   NBA        1     1961  10/28/1960
# ...           ...           ...   ...      ...      ...         ...
# 126252      63127  201505080LAC   NBA        0     2015    5/8/2015
# 126260      63131  201505100LAC   NBA        0     2015   5/10/2015
# 126268      63135  201505120HOU   NBA        1     2015   5/12/2015
# 126276      63139  201505140LAC   NBA        0     2015   5/14/2015
# 126282      63142  201505170HOU   NBA        1     2015   5/17/2015
#
#         seasongame  is_playoffs team_id   fran_id  ...  win_equiv  opp_id  \
# 9730             1            0     LAL    Lakers  ...  35.369419     CIN
# ...

# %%
df_la_base_team[
    df_la_base_team.year_id >= 2000
].groupby(["fran_id", "game_result"])["game_result"].count()
# Out:
# fran_id   game_result
# Clippers  L              750
#           W              602
# Lakers    L              592
#           W              901
# Name: game_result, dtype: int64

# %%
df_la_base_team[
    (df_la_base_team.game_result == "L")
    & (df_la_base_team.fran_id == "Clippers")
    & (df_la_base_team.year_id >= 2000)
].shape[0]
# Out:
# 750

# %%
df_la_base_team[
    (df_la_base_team.game_result == "W")
    & (df_la_base_team.fran_id == "Clippers")
    & (df_la_base_team.year_id >= 2000)
].shape[0]
# Out:
# 602
